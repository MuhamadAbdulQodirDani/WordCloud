# %% [markdown]
# # Menampilkan Data dalam Bentuk WorldCloud

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
alamat = "/content/Copy of Data Statistik Channel YT Nabawi TV.xlsx"
dyoutube = pd.read_excel(alamat)
dyoutube.head(5)
# Out:
#                                           Unnamed: 0  SL7JmD8I078  Unnamed: 2  \
# 0  🔴LIVE - Kajian Kitab Adab - Habib Muhammad bin...  7yzrnoPrWvs        2668
# 1  🔴LIVE Maulid Agung - Masjid Keramat Empang Bog...  7B92gv0KLRA       76304
# 2  Prof Dr. Said Agil Al Munawwar Melantunkan Qas...  bwJuWMUyWdI        3380
# 3  🔴LIVE Haflah Maulid Nabi Muhammad SAW di Darul...  7yatzl18pao        7620
# 4  🔴LIVE Maulid Akbar & Haul Habib Ali bin Husein...  ymhV6lPPwJw       40970
#
#    Unnamed: 3  Unnamed: 4  Unnamed: 5 Unnamed: 6  \
# 0         137         NaN           0   00:00:00
# 1        3147         NaN           0   00:00:00
# 2         241         NaN           0   00:06:20
# 3         365         NaN           0   00:00:00
# 4        1584         NaN           0   00:00:00
#
#                                           Unnamed: 7            Unnamed: 8
# 0  #NabawiTV #malang   #binanies \n\nKajian Kitab...  2024-10-01T15:58:43Z
# ...

# %% [markdown]
# # Membuat WorldCloud

# %%
from wordcloud import WordCloud, STOPWORDS
comment_words = ''
stopwords = set(STOPWORDS)

# Iterate througth the csv file
for val in dyoutube["Unnamed: 0"]:

  #Typecaste each val to sttring
  val = str(val)

  # Split the value
  tokens = val.split()

  # Converts each token into lowercase
  for i in range(len(tokens)):
    tokens[i] = tokens[i].lower()

  comment_words += " ".join(tokens)+" "

worldcloud = WordCloud(width = 800, height = 800,
                       background_color = 'white',
                       stopwords = stopwords,
                       min_font_size = 10).generate(comment_words)

# Plot the WordCloud Image
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(worldcloud)
plt.axis("off")
plt.tight_layout(pad = 0)

plt.show()
